# %% [markdown]
# <a href="https://colab.research.google.com/github/Farrukh-Maruf/Basic-Programming-and-Practice/blob/main/practicum_datasets.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
import pandas as pd

# %%
from pandas import Series

# %%
from pandas import DataFrame

# %%
data = pd.Series(np.random.randn(9), index=['a','a','a','b','b','c','c','d','d'])
data.index
# Out:
# Index(['a', 'a', 'a', 'b', 'b', 'c', 'c', 'd', 'd'], dtype='object')

# %%
data1 = pd.Series(np.random.randn(9), index=[['a','a','a','b','b','c','c','d','d'],[1,2,3,1,23,1,2,2,3]])
data1
# Out:
# a  1    -0.224477
#    2    -0.119801
#    3    -0.184502
# b  1     0.195885
#    23    0.004832
# c  1    -0.992986
#    2     0.832611
# d  2     0.491885
#    3     0.255585
# dtype: float64

# %%
data1[['a','c']]
# Out:
# a  1   -0.224477
#    2   -0.119801
#    3   -0.184502
# c  1   -0.992986
#    2    0.832611
# dtype: float64

# %%
data2 = data1.unstack()
data2
# Out:
#          1         2         3         23
# a -0.224477 -0.119801 -0.184502       NaN
# b  0.195885       NaN       NaN  0.004832
# c -0.992986  0.832611       NaN       NaN
# d       NaN  0.491885  0.255585       NaN

# %%
data2.stack()
# Out:
# a  1    -0.224477
#    2    -0.119801
#    3    -0.184502
# b  1     0.195885
#    23    0.004832
# c  1    -0.992986
#    2     0.832611
# d  2     0.491885
#    3     0.255585
# dtype: float64

# %%
# !git clone https://github.com/MansurCompAI/Practicum_Datasets.git
# Out:
# Cloning into 'Practicum_Datasets'...
# remote: Enumerating objects: 60, done.
# remote: Counting objects: 100% (60/60), done.
# remote: Compressing objects: 100% (55/55), done.
# remote: Total 60 (delta 17), reused 16 (delta 1), pack-reused 0
# Unpacking objects: 100% (60/60), 20.24 MiB | 8.28 MiB/s, done.

# %%
df = pd.read_csv('/content/Practicum_Datasets/world_cities_air_water_quality.csv')
df
# Out:
#                   City                 "Region"                    "Country"  \
# 0        New York City               "New York"   "United States of America"
# 1     Washington, D.C.   "District of Columbia"   "United States of America"
# 2        San Francisco             "California"   "United States of America"
# 3               Berlin                       ""                    "Germany"
# 4          Los Angeles             "California"   "United States of America"
# ...                ...                      ...                          ...
# 3958             Yanbu        "Medina Province"               "Saudi Arabia"
# 3959           Cordoba              "Andalusia"                      "Spain"
# 3960               Vic              "Catalonia"                      "Spain"
# 3961           Segovia       "Castile and Leon"                      "Spain"
# 3962       Zamora city       "Castile and Leon"                      "Spain"
#
#        "AirQuality"   "WaterPollution"
# ...

# %%
columns=['City',	"Region","Country","AirQuality","WaterPollution"]
df.columns=columns
df
# Out:
#                   City                   Region                      Country  \
# 0        New York City               "New York"   "United States of America"
# 1     Washington, D.C.   "District of Columbia"   "United States of America"
# 2        San Francisco             "California"   "United States of America"
# 3               Berlin                       ""                    "Germany"
# 4          Los Angeles             "California"   "United States of America"
# ...                ...                      ...                          ...
# 3958             Yanbu        "Medina Province"               "Saudi Arabia"
# 3959           Cordoba              "Andalusia"                      "Spain"
# 3960               Vic              "Catalonia"                      "Spain"
# 3961           Segovia       "Castile and Leon"                      "Spain"
# 3962       Zamora city       "Castile and Leon"                      "Spain"
#
#       AirQuality  WaterPollution
# ...

# %%
df['Region']= df['Region'].map(lambda x: x.replace('"',""))
df
# Out:
#                   City                 Region                      Country  \
# 0        New York City               New York   "United States of America"
# 1     Washington, D.C.   District of Columbia   "United States of America"
# 2        San Francisco             California   "United States of America"
# 3               Berlin                                           "Germany"
# 4          Los Angeles             California   "United States of America"
# ...                ...                    ...                          ...
# 3958             Yanbu        Medina Province               "Saudi Arabia"
# 3959           Cordoba              Andalusia                      "Spain"
# 3960               Vic              Catalonia                      "Spain"
# 3961           Segovia       Castile and Leon                      "Spain"
# 3962       Zamora city       Castile and Leon                      "Spain"
#
#       AirQuality  WaterPollution
# 0      46.816038       49.504950
# ...

# %%
df['Country']=df['Country'].map(lambda x: x.replace('"',""))
df
# Out:
#                   City                 Region                    Country  \
# 0        New York City               New York   United States of America
# 1     Washington, D.C.   District of Columbia   United States of America
# 2        San Francisco             California   United States of America
# 3               Berlin                                           Germany
# 4          Los Angeles             California   United States of America
# ...                ...                    ...                        ...
# 3958             Yanbu        Medina Province               Saudi Arabia
# 3959           Cordoba              Andalusia                      Spain
# 3960               Vic              Catalonia                      Spain
# 3961           Segovia       Castile and Leon                      Spain
# 3962       Zamora city       Castile and Leon                      Spain
#
#       AirQuality  WaterPollution
# 0      46.816038       49.504950
# ...

# %%
df['Country']=df['Country'].map(lambda x: x.strip())
df
df['Region'][2]
# Out:
# ' California'

# %%
df['Region']=df['Region'].map(lambda x: x.strip())
df['Region'][2]
# Out:
# 'California'

# %%
df
# Out:
#                   City                Region                   Country  \
# 0        New York City              New York  United States of America
# 1     Washington, D.C.  District of Columbia  United States of America
# 2        San Francisco            California  United States of America
# 3               Berlin                                         Germany
# 4          Los Angeles            California  United States of America
# ...                ...                   ...                       ...
# 3958             Yanbu       Medina Province              Saudi Arabia
# 3959           Cordoba             Andalusia                     Spain
# 3960               Vic             Catalonia                     Spain
# 3961           Segovia      Castile and Leon                     Spain
# 3962       Zamora city      Castile and Leon                     Spain
#
#       AirQuality  WaterPollution
# 0      46.816038       49.504950
# 1      66.129032       49.107143
# ...

# %%
df[df['Country']=='Spain']
# Out:
#              City               Region Country  AirQuality  WaterPollution
# 116     Barcelona            Catalonia   Spain   35.497238       51.315789
# 240        Madrid  Community of Madrid   Spain   36.234177       18.954248
# 443        Toledo    Castile-La Mancha   Spain   75.000000       50.000000
# 489        Girona            Catalonia   Spain  100.000000        0.000000
# 505    Valladolid     Castile and Leon   Spain   70.000000       41.666667
# ...           ...                  ...     ...         ...             ...
# 3956     Palencia     Castile and Leon   Spain   79.166667       37.500000
# 3959      Cordoba            Andalusia   Spain   85.714286        8.333333
# 3960          Vic            Catalonia   Spain  100.000000        0.000000
# 3961      Segovia     Castile and Leon   Spain  100.000000        0.000000
# 3962  Zamora city     Castile and Leon   Spain  100.000000       50.000000
#
# [78 rows x 5 columns]

# %%
df.to_csv('Updated_pollution_dataset.csv', index= False)

# %%
df
# Out:
#                   City                Region                   Country  \
# 0        New York City              New York  United States of America
# 1     Washington, D.C.  District of Columbia  United States of America
# 2        San Francisco            California  United States of America
# 3               Berlin                                         Germany
# 4          Los Angeles            California  United States of America
# ...                ...                   ...                       ...
# 3958             Yanbu       Medina Province              Saudi Arabia
# 3959           Cordoba             Andalusia                     Spain
# 3960               Vic             Catalonia                     Spain
# 3961           Segovia      Castile and Leon                     Spain
# 3962       Zamora city      Castile and Leon                     Spain
#
#       AirQuality  WaterPollution
# 0      46.816038       49.504950
# 1      66.129032       49.107143
# ...

# %%
df1 = pd.pivot_table(df, index = [ 'Country', 'City'])
df1
# Out:
#                       AirQuality  WaterPollution
# Country     City
# Afghanistan Andkhoy    50.000000       50.000000
#             Farah     100.000000        0.000000
#             Herat      43.750000       31.250000
#             Kabul      18.421053       81.060606
#             Kandahar    0.000000       75.000000
# ...                          ...             ...
# Zambia      Mansa      75.000000       25.000000
# Zimbabwe    Bindura    50.000000       75.000000
#             Bulawayo   67.857143       71.428571
#             Harare     38.461538       87.500000
#             Masvingo   25.000000       62.500000
#
# [3895 rows x 2 columns]

# %%
df1.index
# Out:
# MultiIndex([('Afghanistan',        'Andkhoy'),
#             ('Afghanistan',          'Farah'),
#             ('Afghanistan',          'Herat'),
#             ('Afghanistan',          'Kabul'),
#             ('Afghanistan',       'Kandahar'),
#             ('Afghanistan', 'Mazar-i-Sharif'),
#             (    'Albania',         'Ballsh'),
#             (    'Albania',         'Burrel'),
#             (    'Albania',         'Durres'),
#             (    'Albania',        'Elbasan'),
#             ...
#             (      'Yemen',          'Sanaa'),
#             (      'Yemen',         'Ta'izz'),
#             (     'Zambia',       'Chingola'),
#             (     'Zambia',          'Kitwe'),
#             (     'Zambia',         'Lusaka'),
#             (     'Zambia',          'Mansa'),
#             (   'Zimbabwe',        'Bindura'),
#             (   'Zimbabwe',       'Bulawayo'),
#             (   'Zimbabwe',         'Harare'),
#             (   'Zimbabwe',       'Masvingo')],
# ...

# %%
df1.loc[['Uzbekistan', 'Tajikistan']]
# Out:
#                      AirQuality  WaterPollution
# Country    City
# Uzbekistan Tashkent   56.451613       49.166667
# Tajikistan Dushanbe   41.666667       61.111111

# %%
df2= df1.copy()

# %%
df2['AirPollution']= 100- df2['AirQuality']
df2['WaterQuality']= 100-df2['WaterPollution']
df2
# Out:
#                       AirQuality  WaterPollution  AirPollution  WaterQuality
# Country     City
# Afghanistan Andkhoy    50.000000       50.000000     50.000000     50.000000
#             Farah     100.000000        0.000000      0.000000    100.000000
#             Herat      43.750000       31.250000     56.250000     68.750000
#             Kabul      18.421053       81.060606     81.578947     18.939394
#             Kandahar    0.000000       75.000000    100.000000     25.000000
# ...                          ...             ...           ...           ...
# Zambia      Mansa      75.000000       25.000000     25.000000     75.000000
# Zimbabwe    Bindura    50.000000       75.000000     50.000000     25.000000
#             Bulawayo   67.857143       71.428571     32.142857     28.571429
#             Harare     38.461538       87.500000     61.538462     12.500000
#             Masvingo   25.000000       62.500000     75.000000     37.500000
#
# [3895 rows x 4 columns]

# %%
df3 = pd.DataFrame(df2.values, index= df2.index, columns=[['Air', 'Air', 'Water','Water'],['AirQuality','AirPollution','WaterPollution','WaterQuality']])
df3
# Out:
#                              Air                       Water
#                       AirQuality AirPollution WaterPollution WaterQuality
# Country     City
# Afghanistan Andkhoy    50.000000    50.000000      50.000000    50.000000
#             Farah     100.000000     0.000000       0.000000   100.000000
#             Herat      43.750000    31.250000      56.250000    68.750000
#             Kabul      18.421053    81.060606      81.578947    18.939394
#             Kandahar    0.000000    75.000000     100.000000    25.000000
# ...                          ...          ...            ...          ...
# Zambia      Mansa      75.000000    25.000000      25.000000    75.000000
# Zimbabwe    Bindura    50.000000    75.000000      50.000000    25.000000
#             Bulawayo   67.857143    71.428571      32.142857    28.571429
#             Harare     38.461538    87.500000      61.538462    12.500000
#             Masvingo   25.000000    62.500000      75.000000    37.500000
#
# ...

# %%
df3.columns.names = ['Object:','Info:']
df3
# Out:
# Object:                      Air                       Water
# Info:                 AirQuality AirPollution WaterPollution WaterQuality
# Country     City
# Afghanistan Andkhoy    50.000000    50.000000      50.000000    50.000000
#             Farah     100.000000     0.000000       0.000000   100.000000
#             Herat      43.750000    31.250000      56.250000    68.750000
#             Kabul      18.421053    81.060606      81.578947    18.939394
#             Kandahar    0.000000    75.000000     100.000000    25.000000
# ...                          ...          ...            ...          ...
# Zambia      Mansa      75.000000    25.000000      25.000000    75.000000
# Zimbabwe    Bindura    50.000000    75.000000      50.000000    25.000000
#             Bulawayo   67.857143    71.428571      32.142857    28.571429
#             Harare     38.461538    87.500000      61.538462    12.500000
#             Masvingo   25.000000    62.500000      75.000000    37.500000
#
# ...

# %%
df3.to_csv('very_updated_pollution.csv', index= False)

# %%
df3.sort_index(ascending=False)
# Out:
# Object:                      Air                       Water
# Info:                 AirQuality AirPollution WaterPollution WaterQuality
# Country     City
# Zimbabwe    Masvingo   25.000000    62.500000      75.000000    37.500000
#             Harare     38.461538    87.500000      61.538462    12.500000
#             Bulawayo   67.857143    71.428571      32.142857    28.571429
#             Bindura    50.000000    75.000000      50.000000    25.000000
# Zambia      Mansa      75.000000    25.000000      25.000000    75.000000
# ...                          ...          ...            ...          ...
# Afghanistan Kandahar    0.000000    75.000000     100.000000    25.000000
#             Kabul      18.421053    81.060606      81.578947    18.939394
#             Herat      43.750000    31.250000      56.250000    68.750000
#             Farah     100.000000     0.000000       0.000000   100.000000
#             Andkhoy    50.000000    50.000000      50.000000    50.000000
#
# ...

# %%
df= pd.read_csv("https://github.com/anvarnarz/praktikum_datasets/raw/main/world_population.csv", index_col='country')
df.head()
# Out:
#            rank     density   densityMi   pop2021  area
# country
# Macau         1  21946.4667  56841.3487   658.394    30
# Monaco        2  19755.5000  51166.7450    39.511     2
# Singapore     3   8305.1915  21510.4461  5896.686   710
# Hong Kong     4   6841.3134  17719.0017  7552.810  1104
# Gibraltar     5   5616.3333  14546.3033    33.698     6

# %%
bins = [0,1000, 10000, 30000,50000, 100000, 300000, 1500000]

# %%
population= df.pop2021
population
# Out:
# country
# Macau                658.394
# Monaco                39.511
# Singapore           5896.686
# Hong Kong           7552.810
# Gibraltar             33.698
#                       ...
# Namibia             2587.344
# Western Sahara       611.875
# Mongolia            3329.289
# Falkland Islands       3.533
# Greenland             56.877
# Name: pop2021, Length: 232, dtype: float64

# %%
groups = pd.cut(population, bins)
groups
# Out:
# country
# Macau                   (0, 1000]
# Monaco                  (0, 1000]
# Singapore           (1000, 10000]
# Hong Kong           (1000, 10000]
# Gibraltar               (0, 1000]
#                         ...
# Namibia             (1000, 10000]
# Western Sahara          (0, 1000]
# Mongolia            (1000, 10000]
# Falkland Islands        (0, 1000]
# Greenland               (0, 1000]
# Name: pop2021, Length: 232, dtype: category
# Categories (7, interval[int64, right]): [(0, 1000] < (1000, 10000] < (10000, 30000] <
#                                          (30000, 50000] < (50000, 100000] < (100000, 300000] <
#                                          (300000, 1500000]]

# %%
groups.value_counts()
# Out:
# (0, 1000]            72
# (1000, 10000]        68
# (10000, 30000]       44
# (30000, 50000]       19
# (50000, 100000]      15
# (100000, 300000]     11
# (300000, 1500000]     3
# Name: pop2021, dtype: int64

# %%
df['groups']= groups
df
# Out:
#                   rank     density   densityMi   pop2021     area  \
# country
# Macau                1  21946.4667  56841.3487   658.394       30
# Monaco               2  19755.5000  51166.7450    39.511        2
# Singapore            3   8305.1915  21510.4461  5896.686      710
# Hong Kong            4   6841.3134  17719.0017  7552.810     1104
# Gibraltar            5   5616.3333  14546.3033    33.698        6
# ...                ...         ...         ...       ...      ...
# Namibia            228      3.1338      8.1166  2587.344   825615
# Western Sahara     229      2.3003      5.9577   611.875   266000
# Mongolia           230      2.1286      5.5129  3329.289  1564110
# Falkland Islands   231      0.2902      0.7517     3.533    12173
# Greenland          232      0.0263      0.0680    56.877  2166086
#
#                          groups
# country
# Macau                 (0, 1000]
# Monaco                (0, 1000]
# Singapore         (1000, 10000]
# ...

# %%
df= pd.read_csv("https://github.com/anvarnarz/praktikum_datasets/raw/main/automobile_data.csv", index_col=0)
df.head()
# Out:
#            company   body-style  wheel-base  length engine-type  \
# index
# 0      alfa-romero  convertible        88.6   168.8        dohc
# 1      alfa-romero  convertible        88.6   168.8        dohc
# 2      alfa-romero    hatchback        94.5   171.2        ohcv
# 3             audi        sedan        99.8   176.6         ohc
# 4             audi        sedan        99.4   176.6         ohc
#
#       num-of-cylinders  horsepower  average-mileage    price
# index
# 0                 four         111               21  13495.0
# 1                 four         111               21  16500.0
# 2                  six         154               19  16500.0
# 3                 four         102               24  13950.0
# 4                 five         115               18  17450.0

# %%
df.price.describe()
# Out:
# count       58.000000
# mean     15387.000000
# std      11320.259841
# min       5151.000000
# 25%       6808.500000
# 50%      11095.000000
# 75%      18120.500000
# max      45400.000000
# Name: price, dtype: float64

# %%
bins =[0,10000, 20000, 50000]
range =pd.cut(df.price, bins)
range
# Out:
# index
# 0     (10000, 20000]
# 1     (10000, 20000]
# 2     (10000, 20000]
# 3     (10000, 20000]
# 4     (10000, 20000]
#            ...
# 81        (0, 10000]
# 82        (0, 10000]
# 86        (0, 10000]
# 87    (10000, 20000]
# 88    (10000, 20000]
# Name: price, Length: 61, dtype: category
# Categories (3, interval[int64, right]): [(0, 10000] < (10000, 20000] < (20000, 50000]]

# %%
range.value_counts()
# Out:
# (0, 10000]        28
# (10000, 20000]    17
# (20000, 50000]    13
# Name: price, dtype: int64

# %%
names=['cheap','average','expensive']
range = pd.cut(df.price, bins, labels=names)
range.value_counts()
# Out:
# cheap        28
# average      17
# expensive    13
# Name: price, dtype: int64

# %%
range = pd.cut(df.price, 5)
range.value_counts()
# Out:
# (5110.751, 13200.8]    32
# (13200.8, 21250.6]     14
# (29300.4, 37350.2]      7
# (37350.2, 45400.0]      3
# (21250.6, 29300.4]      2
# Name: price, dtype: int64

# %%
range = pd.qcut(df.price, 5)
range.value_counts()
# Out:
# (5150.999, 6604.6]    12
# (7959.6, 13589.2]     12
# (23719.2, 45400.0]    12
# (6604.6, 7959.6]      11
# (13589.2, 23719.2]    11
# Name: price, dtype: int64

# %%
df.head()
# Out:
#            company   body-style  wheel-base  length engine-type  \
# index
# 0      alfa-romero  convertible        88.6   168.8        dohc
# 1      alfa-romero  convertible        88.6   168.8        dohc
# 2      alfa-romero    hatchback        94.5   171.2        ohcv
# 3             audi        sedan        99.8   176.6         ohc
# 4             audi        sedan        99.4   176.6         ohc
#
#       num-of-cylinders  horsepower  average-mileage    price
# index
# 0                 four         111               21  13495.0
# 1                 four         111               21  16500.0
# 2                  six         154               19  16500.0
# 3                 four         102               24  13950.0
# 4                 five         115               18  17450.0

# %%
df.groupby(['company','body-style']).mean()
# Out:
#                            wheel-base      length  horsepower  \
# company       body-style
# alfa-romero   convertible   88.600000  168.800000  111.000000
#               hatchback     94.500000  171.200000  154.000000
# audi          sedan         99.666667  176.833333  109.000000
#               wagon        105.800000  192.700000  110.000000
# bmw           sedan        103.433333  185.033333  144.833333
# chevrolet     hatchback     91.450000  148.500000   59.000000
#               sedan         94.500000  158.800000   70.000000
# dodge         hatchback     93.700000  157.300000   68.000000
# honda         sedan         96.500000  172.250000  100.500000
#               wagon         96.500000  157.100000   76.000000
# isuzu         sedan         94.433333  160.833333   72.666667
# jaguar        sedan        109.333333  196.966667  204.666667
# mazda         hatchback     93.650000  161.575000   76.250000
#               sedan        104.900000  175.000000   72.000000
# ...

# %%
df.groupby('company').agg([min, max, np.mean])
# Out:
#               wheel-base                    length                     \
#                      min    max        mean    min    max        mean
# company
# alfa-romero         88.6   94.5   90.566667  168.8  171.2  169.600000
# audi                99.4  105.8  101.200000  176.6  192.7  180.800000
# bmw                101.2  110.0  103.433333  176.8  197.0  185.033333
# chevrolet           88.4   94.5   92.466667  141.1  158.8  151.933333
# dodge               93.7   93.7   93.700000  157.3  157.3  157.300000
# honda               96.5   96.5   96.500000  157.1  175.4  167.200000
# isuzu               94.3   94.5   94.433333  155.9  170.7  160.833333
# jaguar             102.0  113.0  109.333333  191.7  199.6  196.966667
# mazda               93.1  104.9   95.900000  159.1  175.0  164.260000
# mercedes-benz      110.0  120.9  113.225000  190.9  208.1  197.275000
# mitsubishi          93.7   96.3   95.000000  157.3  172.4  164.850000
# ...

# %%
df= pd.read_csv("https://github.com/anvarnarz/praktikum_datasets/raw/main/MOCK_USER_DATA.csv", index_col=0)
df.head()
# Out:
#    first_name   last_name                           email       gender   age
# id
# 1     Dorothy     Verryan               dverryan0@who.int   Non-binary     1
# 2     Pietrek     Scanlin          pscanlin1@yolasite.com         Male    91
# 3      Lilith    Sarjeant  lsarjeant2@creativecommons.org  Genderfluid  1233
# 4        Knox  Cunningham    kcunningham3@yellowpages.com  Genderfluid     6
# 5    Mohammed  Habbershon    mhabbershon4@sourceforge.net       Female    48

# %%
df.describe()
# Out:
#                age
# count   100.000000
# mean    145.660000
# std     565.631411
# min     -85.000000
# 25%      22.750000
# 50%      53.500000
# 75%      84.250000
# max    4444.000000

# %%
df[df.age>123].index
# Out:
# Int64Index([3, 39, 47, 49, 65, 80, 100], dtype='int64', name='id')

# %%
df[(df.age<0) | (df.age>123)]
# Out:
#     first_name  last_name                           email       gender   age
# id
# 3       Lilith   Sarjeant  lsarjeant2@creativecommons.org  Genderfluid  1233
# 11      Elijah      Heine                eheinea@imdb.com     Bigender   -85
# 19       Luisa  Bradborne            lbradbornei@fema.gov       Female   -75
# 21       Levin     Worner                lwornerk@ihg.com  Genderqueer   -43
# 33    Ebenezer    Greeves           egreevesw@myspace.com         Male   -26
# 38        Hana   Langwade  hlangwade11@washingtonpost.com  Genderqueer   -42
# 39      Godard      Miere               gmiere12@1688.com   Polygender  3434
# 47       Cleve  Sparshatt      csparshatt1a@economist.com  Genderfluid   333
# 49       Trace   Stockney          tstockney1c@flavors.me       Female   344
# 65      Eloise    Snoddon    esnoddon1s@elegantthemes.com  Genderfluid   332
# 80       Gabie     Rothon              grothon27@ehow.com  Genderqueer  4444
# ...

# %%
df['age']=df['age'].apply(np.abs)

# %%
index= df[df.age>123].index
index
# Out:
# Int64Index([3, 39, 47, 49, 65, 80, 100], dtype='int64', name='id')

# %%
df.drop(index=index, inplace=True)
df.describe
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-77-9b19e9ba518d> in <module>
# ----> 1 df.drop(index=index, inplace=True)
#       2 df.describe
#
# /usr/local/lib/python3.8/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4904                 weight  1.0     0.8
#    4905         """
# -> 4906         return super().drop(
#    4907             labels=labels,
#    4908             axis=axis,
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
# ...

# %%
df.describe()
# Out:
#               age
# count   93.000000
# mean    52.612903
# std     29.978265
# min      1.000000
# 25%     29.000000
# 50%     52.000000
# 75%     77.000000
# max    100.000000

# %%
df.gender.value_counts()
# Out:
# Male           21
# Bigender       12
# Genderfluid    11
# Female         11
# Non-binary     10
# Genderqueer    10
# Agender         9
# Polygender      9
# Name: gender, dtype: int64

# %%
df2=df[df.gender.isin(['Male','Female'])]
df2
# Out:
#    first_name     last_name                         email  gender  age
# id
# 2     Pietrek       Scanlin        pscanlin1@yolasite.com    Male   91
# 5    Mohammed    Habbershon  mhabbershon4@sourceforge.net  Female   48
# 10      David      Meredyth    dmeredyth9@telegraph.co.uk  Female   68
# 12  Raffaello     Firminger     rfirmingerb@bloomberg.com  Female   74
# 17      Byram   Martynikhin     bmartynikhing@jiathis.com    Male   40
# 19      Luisa     Bradborne          lbradbornei@fema.gov  Female   75
# 22        Ray         Padly           rpadlyl@twitpic.com    Male   85
# 26   Ephrayim    Westmacott         ewestmacottp@ning.com    Male   77
# 29      Biron      Acklands        backlandss@comsenz.com    Male   13
# 33   Ebenezer       Greeves         egreevesw@myspace.com    Male   26
# 34     Brooks          Vose             bvosex@amazon.com  Female   34
# 36        Axe       Arundel           aarundelz@yahoo.com  Female   14
# ...

# %%
df= pd.read_csv("https://github.com/anvarnarz/praktikum_datasets/raw/main/MOCK_USER_DATA.csv", index_col=0)
df.head()
# Out:
#    first_name   last_name                           email       gender   age
# id
# 1     Dorothy     Verryan               dverryan0@who.int   Non-binary     1
# 2     Pietrek     Scanlin          pscanlin1@yolasite.com         Male    91
# 3      Lilith    Sarjeant  lsarjeant2@creativecommons.org  Genderfluid  1233
# 4        Knox  Cunningham    kcunningham3@yellowpages.com  Genderfluid     6
# 5    Mohammed  Habbershon    mhabbershon4@sourceforge.net       Female    48

# %%
len(df)
# Out:
# 100

# %%
randlist = np.random.permutation(100)
randlist
# Out:
# array([73, 40, 75, 31, 35, 39, 51, 70, 82, 47, 99, 89, 81, 56, 64, 32, 69,
#        45, 84, 34,  1, 29, 49, 63, 26, 77, 15, 97, 78, 74, 67, 46, 37, 20,
#        87, 48, 83, 22, 54, 76, 98, 80,  3, 59, 66, 95, 61, 27, 52, 10, 86,
#        96, 21, 68, 16,  8, 23,  0, 38, 19, 44, 90, 93, 85, 91,  7, 55,  5,
#        58, 72, 92, 94, 53, 43, 14, 60, 28, 36,  2,  6,  9, 24, 88, 50, 57,
#        13, 25, 42, 12, 71, 30, 79, 17, 18, 62,  4, 65, 11, 33, 41])

# %%
df.take(randlist)
# Out:
#    first_name   last_name                         email       gender  age
# id
# 74      Curry  Smalecombe  csmalecombe21@washington.edu         Male   69
# 41   Katheryn    Ashleigh        kashleigh14@devhub.com      Agender   36
# 76      Misty       Blanc         mblanc23@amazon.co.jp         Male   74
# 32  Mirabelle  Matthewson  mmatthewsonv@list-manage.com      Agender   44
# 36        Axe     Arundel           aarundelz@yahoo.com       Female   14
# ..        ...         ...                           ...          ...  ...
# 5    Mohammed  Habbershon  mhabbershon4@sourceforge.net       Female   48
# 66     Alejoa  Abrahamoff         aabrahamoff1t@com.com   Polygender   28
# 12  Raffaello   Firminger     rfirmingerb@bloomberg.com       Female   74
# 34     Brooks        Vose             bvosex@amazon.com       Female   34
# 42     Dermot      Dragge        ddragge15@google.co.jp  Genderfluid   37
#
# [100 rows x 5 columns]

# %%
df['num-of-cylinders'].unique()
# Out:
# array(['four', 'six', 'five', 'three', 'twelve', 'two', 'eight'],
#       dtype=object)

# %%
dic = {'two':2, 'four':4, 'three': 3,'five':4,'twelve':12, 'six':6,'eight':8 }
df['cylinder']=df['num-of-cylinders'].map(dic)
df
# Out:
#            company   body-style  wheel-base  length engine-type  \
# index
# 0      alfa-romero  convertible        88.6   168.8        dohc
# 1      alfa-romero  convertible         NaN   168.8        dohc
# 2      alfa-romero    hatchback        94.5   171.2        ohcv
# 3             audi        sedan        99.8   176.6         ohc
# 4             audi        sedan        99.4   176.6         ohc
# ...            ...          ...         ...     ...         ...
# 81      volkswagen        sedan        97.3   171.7         ohc
# 82      volkswagen        sedan         NaN   171.7         NaN
# 86      volkswagen        sedan        97.3     NaN         ohc
# 87           volvo        sedan       104.3   188.8         NaN
# 88           volvo        wagon       104.3   188.8         ohc
#
#       num-of-cylinders  horsepower  average-mileage    price  cylinder
# index
# 0                 four         NaN             21.0  13495.0         4
# ...

# %%
exchange=11200
df['price for uzb']=df['price'].map(lambda x:x*exchange)
df
# Out:
#            company   body-style  wheel-base  length engine-type  \
# index
# 0      alfa-romero  convertible        88.6   168.8        dohc
# 1      alfa-romero  convertible         NaN   168.8        dohc
# 2      alfa-romero    hatchback        94.5   171.2        ohcv
# 3             audi        sedan        99.8   176.6         ohc
# 4             audi        sedan        99.4   176.6         ohc
# ...            ...          ...         ...     ...         ...
# 81      volkswagen        sedan        97.3   171.7         ohc
# 82      volkswagen        sedan         NaN   171.7         NaN
# 86      volkswagen        sedan        97.3     NaN         ohc
# 87           volvo        sedan       104.3   188.8         NaN
# 88           volvo        wagon       104.3   188.8         ohc
#
#       num-of-cylinders  horsepower  average-mileage    price  cylinder  \
# index
# 0                 four         NaN             21.0  13495.0         4
# ...

# %%
df.replace(dic)
# Out:
#            company   body-style  wheel-base  length engine-type  \
# index
# 0      alfa-romero  convertible        88.6   168.8        dohc
# 1      alfa-romero  convertible         NaN   168.8        dohc
# 2      alfa-romero    hatchback        94.5   171.2        ohcv
# 3             audi        sedan        99.8   176.6         ohc
# 4             audi        sedan        99.4   176.6         ohc
# ...            ...          ...         ...     ...         ...
# 81      volkswagen        sedan        97.3   171.7         ohc
# 82      volkswagen        sedan         NaN   171.7         NaN
# 86      volkswagen        sedan        97.3     NaN         ohc
# 87           volvo        sedan       104.3   188.8         NaN
# 88           volvo        wagon       104.3   188.8         ohc
#
#        num-of-cylinders  horsepower  average-mileage    price  cylinder  \
# index
# 0                     4         NaN             21.0  13495.0         4
# ...

# %%
df2= pd.read_csv("https://github.com/anvarnarz/praktikum_datasets/raw/main/world_population_duplicates.csv", index_col='country')
df2.head()
# Out:
#          rank     density   densityMi    pop2021   area
# country
# Macau       1  21946.4667  56841.3487    658.394     30
# Monaco      2  19755.5000  51166.7450     39.511      2
# Burundi    28    440.3044   1140.3884  12255.433  27834
# Macau       1  21946.4667  56841.3487    658.394     30
# Monaco      2  19755.5000  51166.7450     39.511      2

# %%
df2.rename(index=str.upper, columns=str.upper)
# Out:
#                   RANK     DENSITY   DENSITYMI    POP2021     AREA
# country
# MACAU                1  21946.4667  56841.3487    658.394       30
# MONACO               2  19755.5000  51166.7450     39.511        2
# BURUNDI             28    440.3044   1140.3884  12255.433    27834
# MACAU                1  21946.4667  56841.3487    658.394       30
# MONACO               2  19755.5000  51166.7450     39.511        2
# ...                ...         ...         ...        ...      ...
# NAMIBIA            228      3.1338      8.1166   2587.344   825615
# WESTERN SAHARA     229      2.3003      5.9577    611.875   266000
# MONGOLIA           230      2.1286      5.5129   3329.289  1564110
# FALKLAND ISLANDS   231      0.2902      0.7517      3.533    12173
# GREENLAND          232      0.0263      0.0680     56.877  2166086
#
# [247 rows x 5 columns]

# %%
df2.rename(columns={'pop2021':'population'}, index={'Macau':'Makau'})
# Out:
#                   rank     density   densityMi  population     area
# country
# Makau                1  21946.4667  56841.3487     658.394       30
# Monaco               2  19755.5000  51166.7450      39.511        2
# Burundi             28    440.3044   1140.3884   12255.433    27834
# Makau                1  21946.4667  56841.3487     658.394       30
# Monaco               2  19755.5000  51166.7450      39.511        2
# ...                ...         ...         ...         ...      ...
# Namibia            228      3.1338      8.1166    2587.344   825615
# Western Sahara     229      2.3003      5.9577     611.875   266000
# Mongolia           230      2.1286      5.5129    3329.289  1564110
# Falkland Islands   231      0.2902      0.7517       3.533    12173
# Greenland          232      0.0263      0.0680      56.877  2166086
#
# [247 rows x 5 columns]

# %%
df.isnull().sum()
# Out:
# company              0
# body-style           0
# wheel-base          15
# length              13
# engine-type         12
# num-of-cylinders     0
# horsepower          16
# average-mileage     15
# price                3
# dtype: int64

# %%
df.dropna()
# Out:
#           company   body-style  wheel-base  length engine-type  \
# index
# 3            audi        sedan        99.8   176.6         ohc
# 5            audi        sedan        99.8   177.3         ohc
# 6            audi        wagon       105.8   192.7         ohc
# 17      chevrolet    hatchback        94.5   155.9         ohc
# 19          dodge    hatchback        93.7   157.3         ohc
# 28          honda        sedan        96.5   175.4         ohc
# 34         jaguar        sedan       113.0   199.6        dohc
# 37          mazda    hatchback        93.1   159.1         ohc
# 38          mazda    hatchback        93.1   159.1         ohc
# 54         nissan        sedan        94.5   165.3         ohc
# 56         nissan        wagon        94.5   170.2         ohc
# 62        porsche  convertible        89.5   168.9        ohcf
# 69         toyota        wagon        95.7   169.7         ohc
# 81     volkswagen        sedan        97.3   171.7         ohc
#
# ...

# %%
len(df.dropna())
# Out:
# 14

# %%
df.dropna(axis=1)
# Out:
#            company   body-style num-of-cylinders
# index
# 0      alfa-romero  convertible             four
# 1      alfa-romero  convertible             four
# 2      alfa-romero    hatchback              six
# 3             audi        sedan             four
# 4             audi        sedan             five
# ...            ...          ...              ...
# 81      volkswagen        sedan             four
# 82      volkswagen        sedan             four
# 86      volkswagen        sedan             four
# 87           volvo        sedan             four
# 88           volvo        wagon             four
#
# [61 rows x 3 columns]

# %%
df.dropna(axis=1, thresh=48)
# Out:
#            company   body-style  length engine-type num-of-cylinders    price
# index
# 0      alfa-romero  convertible   168.8        dohc             four  13495.0
# 1      alfa-romero  convertible   168.8        dohc             four  16500.0
# 2      alfa-romero    hatchback   171.2        ohcv              six  16500.0
# 3             audi        sedan   176.6         ohc             four  13950.0
# 4             audi        sedan   176.6         ohc             five  17450.0
# ...            ...          ...     ...         ...              ...      ...
# 81      volkswagen        sedan   171.7         ohc             four   7975.0
# 82      volkswagen        sedan   171.7         NaN             four   7995.0
# 86      volkswagen        sedan     NaN         ohc             four   9995.0
# 87           volvo        sedan   188.8         NaN             four  12940.0
# 88           volvo        wagon   188.8         ohc             four  13415.0
#
# [61 rows x 6 columns]

# %%
# Out:
#              company   body-style  wheel-base  length engine-type  \
# index
# 0        alfa-romero  convertible        88.6   168.8        dohc
# 1        alfa-romero  convertible         NaN   168.8        dohc
# 2        alfa-romero    hatchback        94.5   171.2        ohcv
# 3               audi        sedan        99.8   176.6         ohc
# 4               audi        sedan        99.4   176.6         ohc
# 5               audi        sedan        99.8   177.3         ohc
# 6               audi        wagon       105.8   192.7         ohc
# 9                bmw        sedan       101.2     NaN         ohc
# 10               bmw        sedan         NaN   176.8         ohc
# 11               bmw        sedan       101.2   176.8         ohc
# 13               bmw        sedan       103.5   189.0         ohc
# 14               bmw        sedan       103.5     NaN         ohc
# 15               bmw        sedan       110.0   197.0         ohc
# ...

# %%
df=pd.read_csv("sample_data/california_housing_test.csv")
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.05     37.37                27.0       3885.0           661.0
# 1    -118.30     34.26                43.0       1510.0           310.0
# 2    -117.81     33.78                27.0       3589.0           507.0
# 3    -118.36     33.82                28.0         67.0            15.0
# 4    -119.67     36.33                19.0       1241.0           244.0
#
#    population  households  median_income  median_house_value
# 0      1537.0       606.0         6.6085            344700.0
# 1       809.0       277.0         3.5990            176500.0
# 2      1484.0       495.0         5.7934            270500.0
# 3        49.0        11.0         6.1359            330000.0
# 4       850.0       237.0         2.9375             81700.0

# %%
obj = df.longitude
obj
# Out:
# 0      -122.05
# 1      -118.30
# 2      -117.81
# 3      -118.36
# 4      -119.67
#          ...
# 2995   -119.86
# 2996   -118.14
# 2997   -119.70
# 2998   -117.12
# 2999   -119.63
# Name: longitude, Length: 3000, dtype: float64

# %%
obj.to_csv("obj.csv")

# %%
pd.read_csv("obj.csv", index_col='longitude', squeeze=True)
# Out:
# longitude
# -122.05       0
# -118.30       1
# -117.81       2
# -118.36       3
# -119.67       4
#            ...
# -119.86    2995
# -118.14    2996
# -119.70    2997
# -117.12    2998
# -119.63    2999
# Name: Unnamed: 0, Length: 3000, dtype: int64

# %%
hdf = pd.HDFStore('data.h5')

# %%
hdf.put("housing", df)

# %%
hdf.keys()
# Out:
# ['/housing']

# %%
hdf['housing']
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0       -122.05     37.37                27.0       3885.0           661.0
# 1       -118.30     34.26                43.0       1510.0           310.0
# 2       -117.81     33.78                27.0       3589.0           507.0
# 3       -118.36     33.82                28.0         67.0            15.0
# 4       -119.67     36.33                19.0       1241.0           244.0
# ...         ...       ...                 ...          ...             ...
# 2995    -119.86     34.42                23.0       1450.0           642.0
# 2996    -118.14     34.06                27.0       5257.0          1082.0
# 2997    -119.70     36.30                10.0        956.0           201.0
# 2998    -117.12     34.10                40.0         96.0            14.0
# 2999    -119.63     34.42                42.0       1765.0           263.0
#
#       population  households  median_income  median_house_value
# ...

# %%
hdf.close()

# %%
data = pd.read_hdf('data.h5')
data
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0       -122.05     37.37                27.0       3885.0           661.0
# 1       -118.30     34.26                43.0       1510.0           310.0
# 2       -117.81     33.78                27.0       3589.0           507.0
# 3       -118.36     33.82                28.0         67.0            15.0
# 4       -119.67     36.33                19.0       1241.0           244.0
# ...         ...       ...                 ...          ...             ...
# 2995    -119.86     34.42                23.0       1450.0           642.0
# 2996    -118.14     34.06                27.0       5257.0          1082.0
# 2997    -119.70     36.30                10.0        956.0           201.0
# 2998    -117.12     34.10                40.0         96.0            14.0
# 2999    -119.63     34.42                42.0       1765.0           263.0
#
#       population  households  median_income  median_house_value
# ...

# %%
data.to_hdf("data1.h5", key="longitude")

# %%
data1 = pd.read_hdf("data1.h5")
data
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0       -122.05     37.37                27.0       3885.0           661.0
# 1       -118.30     34.26                43.0       1510.0           310.0
# 2       -117.81     33.78                27.0       3589.0           507.0
# 3       -118.36     33.82                28.0         67.0            15.0
# 4       -119.67     36.33                19.0       1241.0           244.0
# ...         ...       ...                 ...          ...             ...
# 2995    -119.86     34.42                23.0       1450.0           642.0
# 2996    -118.14     34.06                27.0       5257.0          1082.0
# 2997    -119.70     36.30                10.0        956.0           201.0
# 2998    -117.12     34.10                40.0         96.0            14.0
# 2999    -119.63     34.42                42.0       1765.0           263.0
#
#       population  households  median_income  median_house_value
# ...

# %%
tash = pd.read_html('https://en.wikipedia.org/wiki/Tashkent')

# %%
len(tash)
# Out:
# 17

# %%
tash[5]
# Out:
#    Climate data for Tashkent (1981–2010, extremes 1881–present)  \
#                                                           Month
# 0                                 Record high °C (°F)
# 1                                Average high °C (°F)
# 2                                  Daily mean °C (°F)
# 3                                 Average low °C (°F)
# 4                                  Record low °C (°F)
# 5                   Average precipitation mm (inches)
# 6                          Average precipitation days
# 7                                  Average snowy days
# 8                       Average relative humidity (%)
# 9                         Mean monthly sunshine hours
# 10  Source 1: Centre of Hydrometeorological Servic...
# 11  Source 2: Pogoda.ru.net (mean temperatures/hum...
#
#                                                        \
#                                                   Jan
# 0                                          22.6(72.7)
# ...

# %%
pd.read_json('sample_data/anscombe.json')
# Out:
#    Series   X      Y
# 0       I  10   8.04
# 1       I   8   6.95
# 2       I  13   7.58
# 3       I   9   8.81
# 4       I  11   8.33
# 5       I  14   9.96
# 6       I   6   7.24
# 7       I   4   4.26
# 8       I  12  10.84
# 9       I   7   4.81
# 10      I   5   5.68
# 11     II  10   9.14
# 12     II   8   8.14
# 13     II  13   8.74
# 14     II   9   8.77
# 15     II  11   9.26
# 16     II  14   8.10
# 17     II   6   6.13
# 18     II   4   3.10
# 19     II  12   9.13
# 20     II   7   7.26
# 21     II   5   4.74
# 22    III  10   7.46
# 23    III   8   6.77
# 24    III  13  12.74
# 25    III   9   7.11
# 26    III  11   7.81
# 27    III  14   8.84
# 28    III   6   6.08
# 29    III   4   5.39
# 30    III  12   8.15
# 31    III   7   6.42
# 32    III   5   5.73
# 33     IV   8   6.58
# 34     IV   8   5.76
# 35     IV   8   7.71
# 36     IV   8   8.84
# 37     IV   8   8.47
# 38     IV   8   7.04
# 39     IV   8   5.25
# 40     IV  19  12.50
# 41     IV   8   5.56
# ...

# %%
import requests
r = requests.get('https://openlibrary.org/subjects/python.json?published_in=1990-2022')

# %%
r.status_code
# Out:
# 200

# %%
pd.DataFrame(r.json()['works'])
# Out:
#                    key                                              title  \
# 0    /works/OL2784125W                                    Learning Python
# 1    /works/OL2784127W                                             Python
# 2   /works/OL17795703W                          Python for bioinformatics
# 3    /works/OL6045694W                               Python in a Nutshell
# 4   /works/OL23330617W                        Making music with computers
# 5   /works/OL21349037W  Introduction to Python for Science and Enginee...
# 6   /works/OL21703042W                               Tour of Data Science
# 7   /works/OL19548251W                                Python for Everyone
# 8    /works/OL8167555W             Twisted Network Programming Essentials
# 9   /works/OL14940051W            Natural Language Processing With Python
# 10   /works/OL5841511W                                 The book of Python
# 11  /works/OL25217001W                 Introduction to Python Programming
#
# ...

# %%
import sqlite3 as sql
from pprint import pprint as print

# %%
# !wget https://www.sqlitetutorial.net/wp-content/uploads/2018/03/chinook.zip
# Out:
# --2023-01-08 09:57:44--  https://www.sqlitetutorial.net/wp-content/uploads/2018/03/chinook.zip
# Resolving www.sqlitetutorial.net (www.sqlitetutorial.net)... 151.139.128.10
# Connecting to www.sqlitetutorial.net (www.sqlitetutorial.net)|151.139.128.10|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 305596 (298K) [application/zip]
# Saving to: ‘chinook.zip’
#
# chinook.zip         100%[===================>] 298.43K  --.-KB/s    in 0.02s
#
# 2023-01-08 09:57:44 (12.0 MB/s) - ‘chinook.zip’ saved [305596/305596]

# %%
# !unzip chinook.zip
# Out:
# Archive:  chinook.zip
#   inflating: chinook.db

# %%
db = sql.connect('chinook.db')
cursor =db.cursor()

# %%
cursor.execute("SELECT name FROM sqlite_master WHERE type='tabel';")
cursor.fetchall()
# Out:
# []

# %%
cursor.execute("SELECT COUNT (*) FROM customers")
cursor.fetchone()
# Out:
# (59,)

# %%
cursor.execute ("PRAGMA table_info(customers);")
cursor.fetchall()
# Out:
# [(0, 'CustomerId', 'INTEGER', 1, None, 1),
#  (1, 'FirstName', 'NVARCHAR(40)', 1, None, 0),
#  (2, 'LastName', 'NVARCHAR(20)', 1, None, 0),
#  (3, 'Company', 'NVARCHAR(80)', 0, None, 0),
#  (4, 'Address', 'NVARCHAR(70)', 0, None, 0),
#  (5, 'City', 'NVARCHAR(40)', 0, None, 0),
#  (6, 'State', 'NVARCHAR(40)', 0, None, 0),
#  (7, 'Country', 'NVARCHAR(40)', 0, None, 0),
#  (8, 'PostalCode', 'NVARCHAR(10)', 0, None, 0),
#  (9, 'Phone', 'NVARCHAR(24)', 0, None, 0),
#  (10, 'Fax', 'NVARCHAR(24)', 0, None, 0),
#  (11, 'Email', 'NVARCHAR(60)', 1, None, 0),
#  (12, 'SupportRepId', 'INTEGER', 0, None, 0)]

# %%
cursor.execute("SELECT * FROM customers")
cursor.fetchall()
# Out:
# [(1,
#   'Luís',
#   'Gonçalves',
#   'Embraer - Empresa Brasileira de Aeronáutica S.A.',
#   'Av. Brigadeiro Faria Lima, 2170',
#   'São José dos Campos',
#   'SP',
#   'Brazil',
#   '12227-000',
#   '+55 (12) 3923-5555',
#   '+55 (12) 3923-5566',
#   'luisg@embraer.com.br',
#   3),
#  (2,
#   'Leonie',
#   'Köhler',
#   None,
#   'Theodor-Heuss-Straße 34',
#   'Stuttgart',
#   None,
#   'Germany',
#   '70174',
#   '+49 0711 2842222',
#   None,
#   'leonekohler@surfeu.de',
#   5),
#  (3,
#   'François',
#   'Tremblay',
#   None,
#   '1498 rue Bélanger',
#   'Montréal',
#   'QC',
#   'Canada',
#   'H2G 1A7',
#   '+1 (514) 721-4711',
#   None,
#   'ftremblay@gmail.com',
#   3),
#  (4,
#   'Bjørn',
#   'Hansen',
#   None,
#   'Ullevålsveien 14',
#   'Oslo',
#   None,
#   'Norway',
#   '0171',
#   '+47 22 44 22 22',
#   None,
#   'bjorn.hansen@yahoo.no',
#   4),
#  (5,
#   'František',
#   'Wichterlová',
#   'JetBrains s.r.o.',
#   'Klanova 9/506',
#   'Prague',
#   None,
# ...

# %%
df=pd.read_sql("SELECT CustomerId, FirstName, LastName, Country FROM customers ORDER BY LastName ", db, index_col='CustomerId')
df
# Out:
#             FirstName      LastName         Country
# CustomerId
# 12            Roberto       Almeida          Brazil
# 28              Julia       Barnett             USA
# 39            Camille       Bernard          France
# 18           Michelle        Brooks             USA
# 29             Robert         Brown          Canada
# 21              Kathy         Chase             USA
# 26            Richard    Cunningham             USA
# 41               Marc        Dubois          France
# 34               João     Fernandes        Portugal
# 30             Edward       Francis          Canada
# 42              Wyatt        Girard          France
# 1                Luís     Gonçalves          Brazil
# 23               John        Gordon             USA
# 19                Tim         Goyer             USA
# 27            Patrick          Gray             USA
# 7              Astrid        Gruber         Austria
# 56              Diego     Gutiérrez       Argentina
# ...

# %%
query = "SELECT DISTINCT Country FROM customers"
cursor.execute(query)
cursor.fetchall()
# Out:
# [('Brazil',),
#  ('Germany',),
#  ('Canada',),
#  ('Norway',),
#  ('Czech Republic',),
#  ('Austria',),
#  ('Belgium',),
#  ('Denmark',),
#  ('USA',),
#  ('Portugal',),
#  ('France',),
#  ('Finland',),
#  ('Hungary',),
#  ('Ireland',),
#  ('Italy',),
#  ('Netherlands',),
#  ('Poland',),
#  ('Spain',),
#  ('Sweden',),
#  ('United Kingdom',),
#  ('Australia',),
#  ('Argentina',),
#  ('Chile',),
#  ('India',)]

# %%
pd.read_sql(query,db)
# Out:
#            Country
# 0           Brazil
# 1          Germany
# 2           Canada
# 3           Norway
# 4   Czech Republic
# 5          Austria
# 6          Belgium
# 7          Denmark
# 8              USA
# 9         Portugal
# 10          France
# 11         Finland
# 12         Hungary
# 13         Ireland
# 14           Italy
# 15     Netherlands
# 16          Poland
# 17           Spain
# 18          Sweden
# 19  United Kingdom
# 20       Australia
# 21       Argentina
# 22           Chile
# 23           India

# %%
query = "SELECT * FROM customers WHERE country='USA'"
pd.read_sql(query,db)
# Out:
#     CustomerId FirstName    LastName                Company  \
# 0           16     Frank      Harris            Google Inc.
# 1           17      Jack       Smith  Microsoft Corporation
# 2           18  Michelle      Brooks                   None
# 3           19       Tim       Goyer             Apple Inc.
# 4           20       Dan      Miller                   None
# 5           21     Kathy       Chase                   None
# 6           22   Heather     Leacock                   None
# 7           23      John      Gordon                   None
# 8           24     Frank     Ralston                   None
# 9           25    Victor     Stevens                   None
# 10          26   Richard  Cunningham                   None
# 11          27   Patrick        Gray                   None
# 12          28     Julia     Barnett                   None
#
#                       Address            City State Country  PostalCode  \
# ...

# %%
db=sql.connect("newdb.db")
cursor = db.cursor()

# %%
df = pd.read_csv('https://en.wikipedia.org/wiki/Tashkent')
df.to_sql('elect', db)
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-37-14d53bcb9019> in <module>
# ----> 1 df = pd.read_csv('https://en.wikipedia.org/wiki/Tashkent')
#       2 df.to_sql('elect', db)
#
# /usr/local/lib/python3.8/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
query = """
CREATE TABLE IF NOT EXISTS worldpop(
rank INT,
country TEXT PRIMARY KEY,
density DOUBLE,
population DOUBLE NOT NULL,
area INT NOT NULL
);

"""
cursor.execute(query)
db.commit()

# %%
cursor.execute('PRAGMA table_info(worldpop);')
cursor.fetchall()
# Out:
# [(0, 'rank', 'INT', 0, None, 0),
#  (1, 'country', 'TEXT', 0, None, 1),
#  (2, 'density', 'DOUBLE', 0, None, 0),
#  (3, 'population', 'DOUBLE', 1, None, 0),
#  (4, 'area', 'INT', 1, None, 0)]

# %%
query = "INSERT INTO worldpop VALUES (1, 'Macau', 21946, 658.33940, 30)"
cursor.execute(query)
db.commit()

# %%
cursor.execute('SELECT * FROM worldpop')
cursor.fetchall()
# Out:
# [(1, 'Macau', 21946.0, 658.3394, 30)]

# %%
query='INSERT INTO worldpop (country, population, area) VALUES ("Uzbekistan", 33.360, 448.360)'
cursor.execute(query)
db.commit()

# %%
cursor.execute("SELECT * FROM worldpop")
cursor.fetchall()
# Out:
# [(1, 'Macau', 21946.0, 658.3394, 30),
#  (None, 'Uzbekistan', None, 33.36, 448.36)]

# %%
pd.read_sql("SELECT * FROM  worldpop",db)
# Out:
#    rank     country  density  population    area
# 0   1.0       Macau  21946.0    658.3394   30.00
# 1   NaN  Uzbekistan      NaN     33.3600  448.36

# %%
query = "UPDATE worldpop SET rank=133, density=75.8 WHERE country= 'Uzbekistan'"
cursor.execute(query)
db.commit()

# %%
pd.read_sql('SELECT * FROM  worldpop',db)
# Out:
#    rank     country  density  population    area
# 0     1       Macau  21946.0    658.3394   30.00
# 1   133  Uzbekistan     75.8     33.3600  448.36

# %%
query="DELETE FROM worldpop WHERE country='Macau'"
cursor.execute(query)
db.commit()

# %%
pd.read_sql("SELECT * FROM worldpop", db)
# Out:
#    rank     country  density  population    area
# 0   133  Uzbekistan     75.8       33.36  448.36

# %%
df= pd.read_csv("https://github.com/anvarnarz/praktikum_datasets/raw/main/world_population.csv", index_col="rank")
df.head()
# Out:
#         country     density   densityMi   pop2021  area
# rank
# 1         Macau  21946.4667  56841.3487   658.394    30
# 2        Monaco  19755.5000  51166.7450    39.511     2
# 3     Singapore   8305.1915  21510.4461  5896.686   710
# 4     Hong Kong   6841.3134  17719.0017  7552.810  1104
# 5     Gibraltar   5616.3333  14546.3033    33.698     6

# %%
uz = df[df.country=="Uzbekistan"]
uz
# Out:
#          country  density  densityMi    pop2021    area
# rank
# 133   Uzbekistan  75.8511   196.4542  33935.763  447400

# %%
query = """
CREATE TABLE IF NOT EXISTS worldpop(
rank INT,
country TEXT PRIMARY KEY,
density DOUBLE,
population DOUBLE NOT NULL,
area INT NOT NULL
);

"""
cursor.execute(query)
db.commit()

# %%
pd.read_sql("SELECT * FROM worldpop", db)
# Out:
#    rank     country  density  population    area
# 0   133  Uzbekistan     75.8       33.36  448.36

# %%
rank = uz.index.values[0]
country= uz.at[rank,'country']
density = uz.at[rank, 'density']
population = uz.at[rank,'pop2021']
area = uz.at[rank,'area']
print(f"{rank}, {country}, {density},{population}, {area}")
# Out:
# '133, Uzbekistan, 75.8511,33935.763, 447400'

# %%
query = f"""
INSERT INTO worldpop VALUES ({rank}, '{country}', {density},{population}, {area})
"""
cursor.execute(query)
db.commit()
# Out:
# ---------------------------------------------------------------------------
# IntegrityError                            Traceback (most recent call last)
# <ipython-input-56-9cf62e9f9afc> in <module>
#       2 INSERT INTO worldpop VALUES ({rank}, '{country}', {density},{population}, {area})
#       3 """
# ----> 4 cursor.execute(query)
#       5 db.commit()
#
# IntegrityError: UNIQUE constraint failed: worldpop.country

# %%
cursor.execute ("SELECT * FROM worldpop")
cursor.fetchall()
# Out:
# [(133, 'Uzbekistan', 75.8, 33.36, 448.36)]

# %%
# !wget "https://github.com/anvarnarz/praktikum_datasets/raw/main/electricity.db"
# Out:
# --2023-01-08 12:33:01--  https://github.com/anvarnarz/praktikum_datasets/raw/main/electricity.db
# Resolving github.com (github.com)... 140.82.114.3
# Connecting to github.com (github.com)|140.82.114.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/anvarnarz/praktikum_datasets/main/electricity.db [following]
# --2023-01-08 12:33:01--  https://raw.githubusercontent.com/anvarnarz/praktikum_datasets/main/electricity.db
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 565248 (552K) [application/octet-stream]
# Saving to: ‘electricity.db’
#
# electricity.db      100%[===================>] 552.00K  --.-KB/s    in 0.04s
#
# ...

# %%
db = sql.connect('electricity.db')
cursor= db.cursor()

# %%
cursor.execute("SELECT name  FROM sqlite_master WHERE type='table';")
print(cursor.fetchall())
# Out:
# [('elect',)]

# %%
cursor.execute(' PRAGMA table_info(elect);')
cursor.fetchall( )
# Out:
# [(0, 'index', 'INTEGER', 0, None, 0),
#  (1, 'country', 'TEXT', 0, None, 0),
#  (2, 'code', 'TEXT', 0, None, 0),
#  (3, 'year', 'INTEGER', 0, None, 0),
#  (4, 'coal', 'REAL', 0, None, 0),
#  (5, 'gas', 'REAL', 0, None, 0),
#  (6, 'hydro', 'REAL', 0, None, 0),
#  (7, 'renewable_other', 'REAL', 0, None, 0),
#  (8, 'solar', 'REAL', 0, None, 0),
#  (9, 'oil', 'REAL', 0, None, 0),
#  (10, 'wind', 'REAL', 0, None, 0),
#  (11, 'nuclear', 'REAL', 0, None, 0)]

# %%
pd.read_sql("SELECT * FROM elect LIMIT 15", db, index_col='index')
# Out:
#            country code  year  coal    gas  hydro  renewable_other   solar  \
# index
# 0      Afghanistan  AFG  2000   0.0  0.155  0.312              0.0  0.0000
# 1      Afghanistan  AFG  2001   0.0  0.094  0.498              0.0  0.0000
# 2      Afghanistan  AFG  2002   0.0  0.132  0.555              0.0  0.0000
# 3      Afghanistan  AFG  2003   0.0  0.309  0.630              0.0  0.0000
# 4      Afghanistan  AFG  2004   0.0  0.329  0.565              0.0  0.0000
# 5      Afghanistan  AFG  2005   0.0  0.344  0.590              0.0  0.0000
# 6      Afghanistan  AFG  2006   0.0  0.200  0.637              0.0  0.0000
# 7      Afghanistan  AFG  2007   0.0  0.198  0.748              0.0  0.0000
# 8      Afghanistan  AFG  2008   0.0  0.186  0.542              0.0  0.0000
# 9      Afghanistan  AFG  2009   0.0  0.162  0.776              0.0  0.0000
# 10     Afghanistan  AFG  2010   0.0  0.185  0.751              0.0  0.0002
# ...

# %%
query= "SELECT DISTINCT country FROM elect"
count = pd.read_sql(query, db)

# %%
"Uzbekistan" in count['country'].values
# Out:
# True

# %%
query= "SELECT * FROM elect WHERE COUNTRY='Uzbekistan'"
pd.read_sql(query,db)
# Out:
#     index     country code  year       coal        gas     hydro  \
# 0    5964  Uzbekistan  UZB  2000  11.602405  25.523451  5.817000
# 1    5965  Uzbekistan  UZB  2001  11.766320  25.884038  5.899000
# 2    5966  Uzbekistan  UZB  2002  12.214374  26.869686  6.124000
# 3    5967  Uzbekistan  UZB  2003  11.833513  26.031852  7.544000
# 4    5968  Uzbekistan  UZB  2004  11.595776  25.508869  8.920000
# 5    5969  Uzbekistan  UZB  2005  11.490919  25.278199  8.838000
# 6    5970  Uzbekistan  UZB  2006  11.827788  26.019258  4.653000
# 7    5971  Uzbekistan  UZB  2007  12.051665  26.511751  4.610000
# 8    5972  Uzbekistan  UZB  2008  10.774273  23.701692  4.443000
# 9    5973  Uzbekistan  UZB  2009   9.084625  28.017530  6.418000
# 10   5974  Uzbekistan  UZB  2010   9.792027  30.199200  8.110000
# 11   5975  Uzbekistan  UZB  2011  10.534094  32.487781  5.646000
# 12   5976  Uzbekistan  UZB  2012  10.365016  31.966333  6.586000
# ...

# %%
query= "SELECT country, year, coal, gas, hydro, oil FROM elect WHERE country='Uzbekistan' AND year>2010"
df= pd.read_sql(query,db)
df
# Out:
#       country  year       coal        gas     hydro       oil
# 0  Uzbekistan  2011  10.534094  32.487781  5.646000  1.253064
# 1  Uzbekistan  2012  10.365016  31.966333  6.586000  1.232952
# 2  Uzbekistan  2013  10.939346  33.737603  5.647000  1.301270
# 3  Uzbekistan  2014  11.112674  34.272157  6.014000  1.321888
# 4  Uzbekistan  2015  10.519789  35.780629  6.998000  1.251363
# 5  Uzbekistan  2016  10.783891  36.678911  7.254000  1.282778
# 6  Uzbekistan  2017  10.998707  37.409561  8.343000  1.308332
# 7  Uzbekistan  2018  11.853192  40.315893  5.838030  1.409975
# 8  Uzbekistan  2019  12.297660  41.827647  5.451373  1.462846

# %%
query= "SELECT country, year, coal, gas, hydro, oil FROM elect WHERE country='Uzbekistan' AND year BETWEEN 2005 and 2015"
pd.read_sql(query,db)
# Out:
#        country  year       coal        gas  hydro       oil
# 0   Uzbekistan  2005  11.490919  25.278199  8.838  1.366882
# 1   Uzbekistan  2006  11.827788  26.019258  4.653  1.406953
# 2   Uzbekistan  2007  12.051665  26.511751  4.610  1.433584
# 3   Uzbekistan  2008  10.774273  23.701692  4.443  1.281634
# 4   Uzbekistan  2009   9.084625  28.017530  6.418  1.080645
# 5   Uzbekistan  2010   9.792027  30.199200  8.110  1.164793
# 6   Uzbekistan  2011  10.534094  32.487781  5.646  1.253064
# 7   Uzbekistan  2012  10.365016  31.966333  6.586  1.232952
# 8   Uzbekistan  2013  10.939346  33.737603  5.647  1.301270
# 9   Uzbekistan  2014  11.112674  34.272157  6.014  1.321888
# 10  Uzbekistan  2015  10.519789  35.780629  6.998  1.251363

# %%
query= "SELECT country, year, coal, gas, hydro, oil FROM elect WHERE country='Uzbekistan' AND year  IN (1990,1995,2005)"
pd.read_sql(query,db)
# Out:
#       country  year       coal        gas  hydro       oil
# 0  Uzbekistan  2005  11.490919  25.278199  8.838  1.366882
# 1  Uzbekistan  1990        NaN        NaN  6.648       NaN
# 2  Uzbekistan  1995        NaN        NaN  6.188       NaN
